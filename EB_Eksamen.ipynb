# %%
import json

import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import Imputer
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans 
import urllib
import requests
import warnings
warnings.filterwarnings ('ignore')
import requests
import csv
from contextlib import closing
import matplotlib.pyplot as plt
# %matplotlib inline

import urllib.request
from subprocess import check_output

# %%
#Henter data in fra Amazon server fra EB
df_total = pd.DataFrame(columns = [])

#starter med at hente datasæt 10-20 for at analysere mnindre data til at starte med
for i in range(10,20): 
    file_path = "https://s3-eu-west-1.amazonaws.com/cbsdump/cbs_2018_ga_data/bq%252Fcbs_2018_dump_0000000000" + str(i)
    #print(file_path)
    print("Loading dataset: {}".format(file_path))
    data_temp_1 = pd.read_csv(file_path, compression = 'gzip')
    df_total = pd.concat([df_total, data_temp_1], axis = 0)

    #laver en pickle fil for at kunne åbne meget data hurtigt, man vil også kunne lave det til en CSV fil
df_total.to_pickle('eb_data_total_dataframe_1.pkl')
# Out:
# Loading dataset: https://s3-eu-west-1.amazonaws.com/cbsdump/cbs_2018_ga_data/bq%252Fcbs_2018_dump_000000000010
# Loading dataset: https://s3-eu-west-1.amazonaws.com/cbsdump/cbs_2018_ga_data/bq%252Fcbs_2018_dump_000000000011
# Loading dataset: https://s3-eu-west-1.amazonaws.com/cbsdump/cbs_2018_ga_data/bq%252Fcbs_2018_dump_000000000012
# Loading dataset: https://s3-eu-west-1.amazonaws.com/cbsdump/cbs_2018_ga_data/bq%252Fcbs_2018_dump_000000000013
# Loading dataset: https://s3-eu-west-1.amazonaws.com/cbsdump/cbs_2018_ga_data/bq%252Fcbs_2018_dump_000000000014
# Loading dataset: https://s3-eu-west-1.amazonaws.com/cbsdump/cbs_2018_ga_data/bq%252Fcbs_2018_dump_000000000015
# Loading dataset: https://s3-eu-west-1.amazonaws.com/cbsdump/cbs_2018_ga_data/bq%252Fcbs_2018_dump_000000000016
# Loading dataset: https://s3-eu-west-1.amazonaws.com/cbsdump/cbs_2018_ga_data/bq%252Fcbs_2018_dump_000000000017
# Loading dataset: https://s3-eu-west-1.amazonaws.com/cbsdump/cbs_2018_ga_data/bq%252Fcbs_2018_dump_000000000018
# Loading dataset: https://s3-eu-west-1.amazonaws.com/cbsdump/cbs_2018_ga_data/bq%252Fcbs_2018_dump_000000000019

# %%
#Her henter vi datafil 0-10 fordi det er nemmere at gøre seperat

for j in range(0,10): 
    file_path = "https://s3-eu-west-1.amazonaws.com/cbsdump/cbs_2018_ga_data/bq%252Fcbs_2018_dump_00000000000" + str(i)
    print(file_path)
    print("Loading dataset: {}".format(file_path))
    data_temp_2 = pd.read_csv(file_path, compression = 'gzip')
    df_total = pd.concat([df_total, data_temp_2], axis = 0)
  #Her gør vi det samme som oven over  
df_total.to_pickle('eb_data_total_dataframe_2.pkl')

# %%
#Denne tæller hvor mange instanser der er i hver kolonne 
df_total.count()
# Out:
# id            6324860
# date          6919340
# hour          6919340
# path          6919340
# section       6888848
# subscriber    6888848
# type          6888849
# region        6919340
# pageviews     6919340
# dtype: int64

# %%
#Denne viser dataen generelt, der er sat tallet 10 for at vise de første 10 rækker
df_total.head(10)
# Out:
#    id      date  hour path  section  subscriber             type     region  \
# 0 NaN  20180905    17    /      1.0   anonymous  sektionsforside  (not set)
# 1 NaN  20180317     2    /      1.0   anonymous  sektionsforside  (not set)
# 2 NaN  20180113    19    /      1.0  registered  sektionsforside  (not set)
# 3 NaN  20181207    18    /      1.0   anonymous  sektionsforside  (not set)
# 4 NaN  20181108     4    /      1.0   anonymous  sektionsforside  (not set)
# 5 NaN  20180608     2    /      1.0   anonymous  sektionsforside  (not set)
# 6 NaN  20180727     7    /      1.0  registered  sektionsforside  (not set)
# 7 NaN  20180925    18    /      1.0   anonymous  sektionsforside  (not set)
# 8 NaN  20180609    11    /      1.0   anonymous  sektionsforside  (not set)
# 9 NaN  20181025    10    /      1.0   anonymous  sektionsforside  (not set)
#
#    pageviews
# 0         18
# 1          5
# 2          5
# 3          7
# 4          1
# 5          6
# 6          1
# 7         38
# 8         29
# 9         99

# %%
#Nu læser vi csv filen fra Dan 
df_article = pd.read_csv('articledata.csv',encoding='latin-1')

# %%
#Gør det samme som ovenfor 
df_article.head(10)
# Out:
#    Unnamed: 0       id                                             title  \
# 0           1  3000000                                   tester æøå, ÆØÅ
# 1           2  3000004                                             aaaaa
# 2           3  3000011                           Paula i bitter nabokrig
# 3           4  3000012  Emily Blunt får ikke sunget serenader hver aften
# 4           5  3000013  Emily Blunt får ikke sunget serenader hver aften
# 5           6  3000017                                    Test Mercury 1
# 6           7  3000022                    Hanks beskyldt for mishandling
# 7           8  3000030                     Terrorsag afbrudt før klimaks
# 8           9  3000035                Børn fundet døde i grotesk mordsag
# 9          10  3000040                        Poker: Carlos ude i London
#
#          byline        homesection          publishdate
# 0           NaN       New Articles  2007-10-15 12:20:21
# 1           NaN       New Articles  2007-10-26 09:40:35
# 2           NaN       New Articles  2007-11-27 15:52:06
# 3           NaN              flash  2007-11-27 16:14:00
# 4           NaN              flash  2007-11-27 16:15:03
# 5           NaN  sportsub123456789  2007-11-28 18:16:01
# 6   Niklas Roar       Intl. kendte  2006-09-20 11:24:18
# 7      /ritzau/            Politik  2006-10-18 17:12:45
# 8  Mikkel Selin                112  2006-09-24 07:19:14
# 9  Jonas Hüttel              Poker  2006-09-23 23:01:18

# %%
#Her merger vi de to filer
#Dette giver os attributterne title, homesection, publishdate
# ID'et bruger vi til at sammenligne de to filer 

result = pd.merge(df_total,
                 df_article[['title', 'homesection', 'publishdate', 'id']],
                 on='id')
result.head()
# Out:
#           id      date  hour                path  section  subscriber  \
# 0  6981417.0  20180103    19  /side9/lea/6981417    572.0   anonymous
# 1  6981417.0  20180106     8  /side9/lea/6981417    572.0  registered
# 2  6981417.0  20180103    18  /side9/lea/6981417    572.0  registered
# 3  6981417.0  20180107     8  /side9/lea/6981417    572.0   anonymous
# 4  6981417.0  20180610    15  /side9/lea/6981417    572.0   anonymous
#
#       type          region  pageviews title homesection          publishdate
# 0  artikel       (not set)          1   Lea      Side 9  2018-01-03 02:00:00
# 1  artikel  Region Zealand          2   Lea      Side 9  2018-01-03 02:00:00
# 2  artikel  Region Zealand         11   Lea      Side 9  2018-01-03 02:00:00
# 3  artikel  Region Zealand         11   Lea      Side 9  2018-01-03 02:00:00
# 4  artikel  Region Zealand          1   Lea      Side 9  2018-01-03 02:00:00

# %%
result.head()
# Out:
#           id      date  hour                path  section  subscriber  \
# 0  6981417.0  20180103    19  /side9/lea/6981417    572.0   anonymous
# 1  6981417.0  20180106     8  /side9/lea/6981417    572.0  registered
# 2  6981417.0  20180103    18  /side9/lea/6981417    572.0  registered
# 3  6981417.0  20180107     8  /side9/lea/6981417    572.0   anonymous
# 4  6981417.0  20180610    15  /side9/lea/6981417    572.0   anonymous
#
#       type          region  pageviews title homesection          publishdate
# 0  artikel       (not set)          1   Lea      Side 9  2018-01-03 02:00:00
# 1  artikel  Region Zealand          2   Lea      Side 9  2018-01-03 02:00:00
# 2  artikel  Region Zealand         11   Lea      Side 9  2018-01-03 02:00:00
# 3  artikel  Region Zealand         11   Lea      Side 9  2018-01-03 02:00:00
# 4  artikel  Region Zealand          1   Lea      Side 9  2018-01-03 02:00:00

# %%
# Tæller antallet af Nan i ID kolonnen, bemærk at det er i Df_total datasættet og IKKE result
df_total.id.isna().sum()
# Out:
# 594480

# %%
# Her er det muligt at tælle antallet af attributter i en specifik kolonne
set(result.region)
# Out:
# {'(not set)',
#  'Capital Region of Denmark',
#  'Central Denmark Region',
#  'North Denmark Region',
#  'Region Syddanmark',
#  'Region Zealand',
#  'Region of Southern Denmark'}

# %%
# Tæller hvor mange der er i region
result.region.count()
# Out:
# 6249904

# %%
# tæller antallet af instanser i attributterne i region objektet
from collections import Counter
Counter(result.region)
# Out:
# Counter({'(not set)': 24387,
#          'Region Zealand': 859600,
#          'Region Syddanmark': 134990,
#          'North Denmark Region': 704995,
#          'Central Denmark Region': 1253592,
#          'Capital Region of Denmark': 2303255,
#          'Region of Southern Denmark': 969085})

# %%
# viser den nye data efter filerne er blevet merget
result.head()
# Out:
#           id      date  hour                path  section  subscriber  \
# 0  6981417.0  20180103    19  /side9/lea/6981417    572.0   anonymous
# 1  6981417.0  20180106     8  /side9/lea/6981417    572.0  registered
# 2  6981417.0  20180103    18  /side9/lea/6981417    572.0  registered
# 3  6981417.0  20180107     8  /side9/lea/6981417    572.0   anonymous
# 4  6981417.0  20180610    15  /side9/lea/6981417    572.0   anonymous
#
#       type          region  pageviews title homesection          publishdate
# 0  artikel       (not set)          1   Lea      Side 9  2018-01-03 02:00:00
# 1  artikel  Region Zealand          2   Lea      Side 9  2018-01-03 02:00:00
# 2  artikel  Region Zealand         11   Lea      Side 9  2018-01-03 02:00:00
# 3  artikel  Region Zealand         11   Lea      Side 9  2018-01-03 02:00:00
# 4  artikel  Region Zealand          1   Lea      Side 9  2018-01-03 02:00:00

# %%
# Tæller antallet af kolonner med null values i df_total datasættet
len(df_total) - df_total.count()
# Out:
# id            594480
# date               0
# hour               0
# path               0
# section        30492
# subscriber     30492
# type           30491
# region             0
# pageviews          0
# dtype: int64

# %%
# Tæller antallet af kolonner med null values i result datasættet
len(result) - result.count()
# Out:
# id             0
# date           0
# hour           0
# path           0
# section        0
# subscriber     0
# type           0
# region         0
# pageviews      0
# title          0
# homesection    0
# publishdate    0
# dtype: int64

# %%
#morgen 6-10
#middag 10-17
#aften 17-0 
#nat 0-6
result['hour'].hist(bins=4)

# %%
views_hours =pd.DataFrame()
grouped = result.groupby('hour')['pageviews'].sum()
list_hours = [x for x in range(0,24)]
views_hours['hour'] = pd.Series(list_hours)
views_hours['views'] = pd.Series(grouped)

# %%
result.groupby('hour')['pageviews'].sum()
# Out:
# hour
# 0      3892521
# 1      1859006
# 2      1176049
# 3      1052078
# 4      1598074
# 5      4213800
# 6      8942425
# 7     11743439
# 8     13255167
# 9     12850151
# 10    10643725
# 11    10520083
# 12    11354900
# 13    10311110
# 14     9839456
# 15    10267821
# 16    10981060
# 17    10701584
# 18    10405229
# 19    11014831
# 20    11289190
# 21    12099374
# 22    11362446
# 23     7485867
# Name: pageviews, dtype: int64

# %%
views_hours
# Out:
#     hour     views
# 0      0   3892521
# 1      1   1859006
# 2      2   1176049
# 3      3   1052078
# 4      4   1598074
# 5      5   4213800
# 6      6   8942425
# 7      7  11743439
# 8      8  13255167
# 9      9  12850151
# 10    10  10643725
# 11    11  10520083
# 12    12  11354900
# 13    13  10311110
# 14    14   9839456
# 15    15  10267821
# 16    16  10981060
# 17    17  10701584
# 18    18  10405229
# 19    19  11014831
# 20    20  11289190
# 21    21  12099374
# 22    22  11362446
# 23    23   7485867

# %%
result.to_csv('TEST.csv')

# %%
#Laver en ny inddeling og kalder den Time_of_Day 
binInterval = [-1, 6, 12, 18, 23]
binLabels   = ["Night", "Morning", "Noon", "Evening"]
result['Time_of_Day'] = pd.cut(result['hour'], bins = binInterval, labels=binLabels)

# %%
#Laver en ny inddeling og kalder den Time_of_Day 
binLabels   = ["Region Zealand", "Capital Region of Denmark", "Central Denmark Region", "North Denmark Region","Region Syddanmark","Region of Southern Denmark"]
binInterval = [1, 2, 3, 4, 5, 6]
result['Region2'] = pd.cut(result['region'], labels=binLabels, bins = binInterval,)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-e0d642841d0b> in <module>()
#       2 binLabels   = ["Region Zealand", "Capital Region of Denmark", "Central Denmark Region", "North Denmark Region","Region Syddanmark","Region of Southern Denmark"]
#       3 binInteger = [1, 2, 3, 4, 5, 6]
# ----> 4 result['Region2'] = pd.cut(result['region'], labels=binLabels, bins = binInterval,)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/reshape/tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates)
#     232                               include_lowest=include_lowest,
#     233                               dtype=dtype,
# --> 234                               duplicates=duplicates)
#     235
#     236     return _postprocess_for_cut(fac, bins, retbins, x_is_series,
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/reshape/tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates)
#     335
#     336     side = 'left' if right else 'right'
# --> 337     ids = _ensure_int64(bins.searchsorted(x, side=side))
#     338
#     339     if include_lowest:
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
'Capital Region of Denmark',
 'Central Denmark Region',
 'North Denmark Region',
 'Region Syddanmark',
 'Region Zealand',
 'Region of Southern Denmark

# %%
Counter(result.Time_of_Day)
# Out:
# Counter({'Evening': 1606447,
#          'Morning': 1819515,
#          'Noon': 1851348,
#          'Night': 972594})

# %%
result.head(5)
# Out:
#           id      date  hour                path  section  subscriber  \
# 0  6981417.0  20180103    19  /side9/lea/6981417    572.0   anonymous
# 1  6981417.0  20180106     8  /side9/lea/6981417    572.0  registered
# 2  6981417.0  20180103    18  /side9/lea/6981417    572.0  registered
# 3  6981417.0  20180107     8  /side9/lea/6981417    572.0   anonymous
# 4  6981417.0  20180610    15  /side9/lea/6981417    572.0   anonymous
#
#       type          region  pageviews title homesection          publishdate  \
# 0  artikel       (not set)          1   Lea      Side 9  2018-01-03 02:00:00
# 1  artikel  Region Zealand          2   Lea      Side 9  2018-01-03 02:00:00
# 2  artikel  Region Zealand         11   Lea      Side 9  2018-01-03 02:00:00
# 3  artikel  Region Zealand         11   Lea      Side 9  2018-01-03 02:00:00
# 4  artikel  Region Zealand          1   Lea      Side 9  2018-01-03 02:00:00
#
#   binned Time_of_Day
# 0      1     Evening
# 1      3     Morning
# 2      2        Noon
# 3      3     Morning
# 4      2        Noon

# %%
num_list = ['binned','pageviews']
movie_num = result[num_list]
movie_num.head()
# Out:
#   binned  pageviews
# 0      1          1
# 1      3          2
# 2      2         11
# 3      3         11
# 4      2          1

# %%
f, ax = plt.subplots(figsize=(12,10))
plt.title('Pearson Correlation of Movie Features')
sns.heatmap(movie_num.astype(float).corr(), linewidths=0.25, vmax=1.0, square=True,
          cmap="YlGnBu", linecolor='black', annot=True)
